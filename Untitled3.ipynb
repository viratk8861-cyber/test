# %% [markdown]
# <a href="https://colab.research.google.com/github/viratk8861-cyber/test/blob/sales-analyzer-script/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls -l
# Out:
# total 8
# drwx------ 5 root root 4096 Jul  9 03:02 drive/
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 sample_data/

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
ls -l
# Out:
# total 678711
# -rw------- 1 root root       176 Sep 19  2025 '3.1 Lists.gdoc'
# -rw------- 1 root root   8205307 Nov 25  2025  apache-tomcat-7.0.34.zip
# -rw------- 1 root root       176 May  4 03:13  Brochure.gdoc
# drwx------ 2 root root      4096 Sep 19  2025  Classroom/
# drwx------ 2 root root      4096 Jun 29 04:16 'Colab Notebooks'/
# drwx------ 2 root root      4096 Jun 29 04:29  demo/
# -rw------- 1 root root 266781307 Nov 25  2025  eclipse-jee-luna-SR2-win32-x86_64.zip
# drwx------ 2 root root      4096 Feb 17 15:42  gjs/
# -rw------- 1 root root       176 Feb 17 16:41  Gjs.gsheet
# drwx------ 2 root root      4096 Sep 25  2025 'Google AI Studio'/
# drwx------ 2 root root      4096 Sep 22  2025 'Google Earth'/
# -rw------- 1 root root     18535 Jul  9 03:12  heart.csv
# drwx------ 3 root root      4096 Jul  6 04:48  heart_disease/
# drwx------ 3 root root      4096 Jul  7 11:43  HeartDiseasePrediction/
# -rw------- 1 root root       176 May 15 11:15 'Jewelry Survey.gsheet'
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import joblib

# %%
import pandas as pd

path = "/content/drive/MyDrive/heart.csv"

df = pd.read_csv(path)

df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  target
# 0    3.0  0.0   6.0       0
# 1    2.0  3.0   3.0       1
# 2    2.0  2.0   7.0       1
# 3    3.0  0.0   3.0       0
# 4    1.0  0.0   3.0       0
